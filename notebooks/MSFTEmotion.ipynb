# %%
# %matplotlib inline

# %%
import numpy as np
import cv2

from multiprocessing.pool import ThreadPool
from collections import deque
import matplotlib.pyplot as plt
import json
########### Python 2.7 #############
import httplib, urllib, base64
import time
import sys
sys.path.append("../lib")
from load import getValData
from load import faces
import pickle
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
plt.imshow(teX[100][0],cmap = cm.Greys_r)
plt.savefig('tmp1')
image = getPayload("tmp1.png")

# %%
data = makeEmoRequest(image)
print data
# Out:
# 200 OK
# [{u'faceRectangle': {u'width': 188, u'top': 58, u'left': 124, u'height': 188}, u'scores': {u'sadness': 1.48918462e-13, u'neutral': 6.54319e-09, u'contempt': 2.30712021e-12, u'disgust': 5.79227832e-10, u'anger': 2.65131139e-10, u'surprise': 1.445064e-13, u'fear': 3.37625083e-16, u'happiness': 1.0}}]

# %%
face = data[0]
print face['scores']['happiness']
# Out:
# 1.0

# %%
print teX.shape
# Out:
# (3589, 1, 48, 48)
